# %% [markdown]
# # Session5 - pandas

# %%
import pandas

# %%
print(pandas.__version__)
# Out:
# 3.0.2

# %%
#read the dataframe
station_ids = pandas.read_csv(
"../data/Niederschlag_1981-2010_Stationsliste.txt",
delimiter=" *; *",
encoding = "iso-8859-1",
index_col="Stations_id",
engine="python")
#index-col = assign one column as index instead of raw index

# %%
station_ids
# Out:
#                         Stationsname  geogr. Breite  geogr. Laenge  \
# Stations_id
# 1                               Aach      47.841299       8.849299
# 2                Aachen (Kläranlage)      50.806581       6.099638
# 3                             Aachen      50.782659       6.094087
# 4                       Aachen-Brand      50.768313       6.120705
# 6                 Aalen-Unterrombach      48.836072      10.059764
# ...                              ...            ...            ...
# 19697        Wassertrüdingen/Wörnitz      49.046341      10.602684
# 19698                 Werda/Vogtland      50.448020      12.305168
# 19701                Wertingen/Zusam      48.557500      10.674167
# 19706            Oberndorf am Neckar      48.285077       8.576395
# 19781                     Ingolstadt      48.742909      11.423324
#
#              Stationshoehe           Bundesland  Unnamed: 6
# Stations_id
# 1                    478.0    Baden-Württemberg         NaN
# 2                    138.0  Nordrhein-Westfalen         NaN
# 3                    202.0  Nordrhein-Westfalen         NaN
# 4                    243.0  Nordrhein-Westfalen         NaN
# 6                    455.0    Baden-Württemberg         NaN
# ...                    ...                  ...         ...
# 19697                435.0               Bayern         NaN
# 19698                595.0              Sachsen         NaN
# 19701                430.0               Bayern         NaN
# 19706                516.0    Baden-Württemberg         NaN
# 19781                367.0               Bayern         NaN
#
# [5740 rows x 6 columns]

# %%
station_ids.columns #check each coulum name
# Out:
# Index(['Stationsname', 'geogr. Breite', 'geogr. Laenge', 'Stationshoehe',
#        'Bundesland', 'Unnamed: 6'],
#       dtype='str')

# %%
station_ids.info() #get the data frame information
# Out:
# <class 'pandas.DataFrame'>
# Index: 5740 entries, 1 to 19781
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Stationsname   5740 non-null   str
#  1   geogr. Breite  5740 non-null   float64
#  2   geogr. Laenge  5740 non-null   float64
#  3   Stationshoehe  5740 non-null   float64
#  4   Bundesland     5740 non-null   str
#  5   Unnamed: 6     0 non-null      float64
# dtypes: float64(4), str(2)
# memory usage: 313.9 KB

# %%
station_ids.head() #first five row
# Out:
#                                          Stationsname  geogr. Breite  \
# Stations_id
# 1            Aach                                          47.841299
# 2            Aachen (Kläranlage)                           50.806581
# 3            Aachen                                        50.782659
# 4            Aachen-Brand                                  50.768313
# 6            Aalen-Unterrombach                            48.836072
#
#              geogr. Laenge  Stationshoehe  \
# Stations_id
# 1                 8.849299          478.0
# 2                 6.099638          138.0
# 3                 6.094087          202.0
# 4                 6.120705          243.0
# 6                10.059764          455.0
#
#                                            Bundesland  Unnamed: 6
# Stations_id
# 1            Baden-Württemberg                                NaN
# 2            Nordrhein-Westfalen                              NaN
# 3            Nordrhein-Westfalen                              NaN
# 4            Nordrhein-Westfalen                              NaN
# 6            Baden-Württemberg                                NaN

# %%
station_ids.tail() # last five row
# Out:
#                                          Stationsname  geogr. Breite  \
# Stations_id
# 19697        Wassertrüdingen/Wörnitz                       49.046341
# 19698        Werda/Vogtland                                50.448020
# 19701        Wertingen/Zusam                               48.557500
# 19706        Oberndorf am Neckar                           48.285077
# 19781        Ingolstadt                                    48.742909
#
#              geogr. Laenge  Stationshoehe  \
# Stations_id
# 19697            10.602684          435.0
# 19698            12.305168          595.0
# 19701            10.674167          430.0
# 19706             8.576395          516.0
# 19781            11.423324          367.0
#
#                                            Bundesland  Unnamed: 6
# Stations_id
# 19697        Bayern                                           NaN
# 19698        Sachsen                                          NaN
# 19701        Bayern                                           NaN
# 19706        Baden-Württemberg                                NaN
# 19781        Bayern                                           NaN

# %%
station_ids.drop(station_ids.columns[-1], axis=1, inplace=True) #delete (drop) the last column (-1)

# %%
station_ids.columns
# Out:
# Index(['Stationsname', 'geogr. Breite', 'geogr. Laenge', 'Stationshoehe',
#        'Bundesland'],
#       dtype='str')

# %%
station_ids.iloc[2,0] # iloc = index location[row;column] -> select by index
#remember the index start from 0 but we can change it when we read the data frame
# Out:
# 'Aachen                                  '

# %%
station_ids.iloc[:5] # act like head
# Out:
#                                          Stationsname  geogr. Breite  \
# Stations_id
# 1            Aach                                          47.841299
# 2            Aachen (Kläranlage)                           50.806581
# 3            Aachen                                        50.782659
# 4            Aachen-Brand                                  50.768313
# 6            Aalen-Unterrombach                            48.836072
#
#              geogr. Laenge  Stationshoehe  \
# Stations_id
# 1                 8.849299          478.0
# 2                 6.099638          138.0
# 3                 6.094087          202.0
# 4                 6.120705          243.0
# 6                10.059764          455.0
#
#                                            Bundesland
# Stations_id
# 1            Baden-Württemberg
# 2            Nordrhein-Westfalen
# 3            Nordrhein-Westfalen
# 4            Nordrhein-Westfalen
# 6            Baden-Württemberg

# %%
station_ids.iloc[:,1:3] # all rows, all columns [:,:]
# Out:
#              geogr. Breite  geogr. Laenge
# Stations_id
# 1                47.841299       8.849299
# 2                50.806581       6.099638
# 3                50.782659       6.094087
# 4                50.768313       6.120705
# 6                48.836072      10.059764
# ...                    ...            ...
# 19697            49.046341      10.602684
# 19698            50.448020      12.305168
# 19701            48.557500      10.674167
# 19706            48.285077       8.576395
# 19781            48.742909      11.423324
#
# [5740 rows x 2 columns]

# %%
station_ids.loc[3, "Stationsname"] #loc: select by label
# Out:
# 'Aachen                                  '

# %%
station_ids.loc[:,"geogr. Breite":"geogr. Laenge"]
# Out:
#              geogr. Breite  geogr. Laenge
# Stations_id
# 1                47.841299       8.849299
# 2                50.806581       6.099638
# 3                50.782659       6.094087
# 4                50.768313       6.120705
# 6                48.836072      10.059764
# ...                    ...            ...
# 19697            49.046341      10.602684
# 19698            50.448020      12.305168
# 19701            48.557500      10.674167
# 19706            48.285077       8.576395
# 19781            48.742909      11.423324
#
# [5740 rows x 2 columns]

# %%
station_ids.loc[:,'Bundesland'] #select all row from column Bundesland
# Out:
# Stations_id
# 1          Baden-Württemberg
# 2        Nordrhein-Westfalen
# 3        Nordrhein-Westfalen
# 4        Nordrhein-Westfalen
# 6          Baden-Württemberg
#                 ...
# 19697                 Bayern
# 19698                Sachsen
# 19701                 Bayern
# 19706      Baden-Württemberg
# 19781                 Bayern
# Name: Bundesland, Length: 5740, dtype: str

# %%
# group data by 'Bundesland' and sort by 'Stationsname'
# ascending = False or True
station_ids.groupby('Bundesland').count().sort_values("Stationsname")
# Out:
#                         Stationsname  geogr. Breite  geogr. Laenge  \
# Bundesland
# Bremen                            15             15             15
# Hamburg                           19             19             19
# Berlin                            29             29             29
# Saarland                          54             54             54
# Schleswig-Holstein               223            223            223
# Mecklenburg-Vorpommern           237            237            237
# Rheinland-Pfalz                  264            264            264
# Brandenburg                      302            302            302
# Sachsen                          356            356            356
# Thüringen                        391            391            391
# Sachsen-Anhalt                   411            411            411
# Hessen                           436            436            436
# Nordrhein-Westfalen              436            436            436
# Niedersachsen                    611            611            611
# Baden-Württemberg                619            619            619
# Bayern                          1337           1337           1337
#
#                         Stationshoehe  Unnamed: 6
# Bundesland
# Bremen                             15           0
# Hamburg                            19           0
# Berlin                             29           0
# Saarland                           54           0
# Schleswig-Holstein                223           0
# Mecklenburg-Vorpommern            237           0
# Rheinland-Pfalz                   264           0
# Brandenburg                       302           0
# Sachsen                           356           0
# Thüringen                         391           0
# Sachsen-Anhalt                    411           0
# Hessen                            436           0
# Nordrhein-Westfalen               436           0
# Niedersachsen                     611           0
# Baden-Württemberg                 619           0
# Bayern                           1337           0

# %%
mask = station_ids.Bundesland == "Bayern"
#get bolean data series whether that column Bundesland data is "Bayern"

# %%
type(mask)
# Out:
# pandas.Series

# %%
station_ids.Bundesland.iloc[-1]
# Out:
# 'Bayern'

# %%
bayern = station_ids[mask]

# %%
bayern.loc[17]
# Out:
# Stationsname     Abensberg-Sandharlanden
# geogr. Breite                    48.8421
# geogr. Laenge                  11.819366
# Stationshoehe                      380.0
# Bundesland                        Bayern
# Unnamed: 6                           NaN
# Name: 17, dtype: object

# %% [markdown]
# ## Exercise
# * get a list of stations in Berlin
# * figure out the station ID of Alexanderplatz
# * load the 30 year mean precipitation data
#     data/Niederschlag 1981-2010.txt
# * only keep the columns with the monthly means

# %% [markdown]
# ### Step1: get a list of stations in Berlin

# %%
bse = station_ids.Bundesland == "Berlin"

# %%
berlin = station_ids[bse] # list of stations in Berlin

# %% [markdown]
# ### Step2: found Alexanderplatz and got the id

# %%
berlin # just serach and got the id (399)
# Out:
#                           Stationsname  geogr. Breite  geogr. Laenge  \
# Stations_id
# 394                 Berlin (Rosenthal)      52.590285      13.383258
# 399              Berlin-Alexanderplatz      52.519785      13.405678
# 400                        Berlin-Buch      52.630956      13.502135
# 401              Berlin-Charlottenburg      52.516700      13.266700
# 402               Berlin-Dahlem (LFAG)      52.456399      13.299675
# 403                 Berlin-Dahlem (FU)      52.453711      13.301731
# 404             Berlin-Friedrichsfelde      52.504696      13.521539
# 406              Berlin-Friedrichshain      52.516700      13.416700
# 407                     Berlin-Frohnau      52.646077      13.285772
# 409                Berlin-Johannisthal      52.450000      13.500000
# 410                   Berlin-Kaniswall      52.404034      13.730854
# 412                  Berlin-Karlshorst      52.483300      13.516700
# 413                   Berlin-Kaulsdorf      52.504396      13.579930
# 414                    Berlin-Köpenick      52.475300      13.589930
# 416                 Berlin-Lichtenrade      52.406906      13.412659
# 417          Berlin-Lichterfelde (Süd)      52.414404      13.303575
# 418            Berlin-Lichterfelde Ost      52.408905      13.331571
# 419                     Berlin-Malchow      52.575287      13.483243
# 420                     Berlin-Marzahn      52.544744      13.559789
# 421                Berlin-Marzahn, Apw      52.533300      13.550000
# 422                       Berlin-Mitte      52.533300      13.383300
# 425                       Berlin-Rudow      52.404407      13.483848
# 426                 Berlin-Schmöckwitz      52.382302      13.623638
# 429                     Berlin-Spandau      52.566685      13.169392
# 430                       Berlin-Tegel      52.564402      13.308805
# 432           Berlin-Tegeler Fliesstal      52.604382      13.295172
# 433                   Berlin-Tempelhof      52.467451      13.402120
# 434                     Berlin-Treptow      52.455301      13.469949
# 435                  Berlin-Zehlendorf      52.428902      13.232686
#
#              Stationshoehe Bundesland  Unnamed: 6
# Stations_id
# 394                   43.0     Berlin         NaN
# 399                   35.8     Berlin         NaN
# 400                   60.0     Berlin         NaN
# 401                   55.0     Berlin         NaN
# 402                   55.0     Berlin         NaN
# 403                   51.0     Berlin         NaN
# 404                   38.0     Berlin         NaN
# 406                   33.0     Berlin         NaN
# 407                   48.0     Berlin         NaN
# 409                   35.0     Berlin         NaN
# 410                   33.0     Berlin         NaN
# 412                   35.0     Berlin         NaN
# 413                   39.0     Berlin         NaN
# 414                   36.0     Berlin         NaN
# 416                   47.0     Berlin         NaN
# 417                   43.0     Berlin         NaN
# 418                   45.0     Berlin         NaN
# 419                   53.0     Berlin         NaN
# 420                   61.0     Berlin         NaN
# 421                   52.0     Berlin         NaN
# 422                   35.0     Berlin         NaN
# 425                   38.0     Berlin         NaN
# 426                   36.0     Berlin         NaN
# 429                   32.0     Berlin         NaN
# 430                   35.5     Berlin         NaN
# 432                   36.0     Berlin         NaN
# 433                   47.7     Berlin         NaN
# 434                   35.0     Berlin         NaN
# 435                   45.0     Berlin         NaN

# %% [markdown]
# ### Step3: load the 30 years mean precipitation data

# %%
precip_ref = pandas.read_csv(
"data/Niederschlag_1981-2010.txt",
delimiter=" *; *",
encoding = "iso-8859-1",
index_col="Stations_id",
engine="python")

# %%
precip_ref
# Out:
#             Bezugszeitraum  Datenquelle  Jan.  Feb.  März  Apr.    Mai  Jun.  \
# Stations_id
# 1                1981-2010           46  48.4  45.6  49.7  51.5   88.7  93.0
# 2                1981-2010           45  74.3  66.0  64.4  58.2   70.9  79.8
# 3                1981-2010           45  68.1  63.6  67.0  55.7   72.0  80.3
# 4                1981-2010           46  68.9  66.1  67.4  55.9   71.5  81.2
# 6                1981-2010           45  66.2  65.3  75.2  55.8   93.0  83.0
# ...                    ...          ...   ...   ...   ...   ...    ...   ...
# 19697            1981-2010           45  54.4  48.5  56.9  42.7   73.6  76.4
# 19698            1981-2010           45  59.0  54.4  63.9  57.0   75.8  86.0
# 19701            1981-2010           45  46.1  39.8  54.0  52.0   84.1  85.8
# 19706            1981-2010           45  89.0  82.0  82.3  69.9  102.4  84.0
# 19781            1981-2010           45  47.6  40.1  47.6  42.0   75.1  77.9
#
#               Jul.  Aug.  Sept.  Okt.  Nov.  Dez.    Jahr  Unnamed: 16
# Stations_id
# 1             95.7  85.1   62.5  61.3  55.5  60.1   797.1          NaN
# 2             71.4  69.5   69.7  68.4  64.6  78.4   838.6          NaN
# 3             75.2  74.8   69.2  70.0  66.1  75.5   837.4          NaN
# 4             75.2  73.2   68.8  69.3  65.2  76.5   839.2          NaN
# 6             95.8  79.2   69.8  67.3  67.7  80.2   898.4          NaN
# ...            ...   ...    ...   ...   ...   ...     ...          ...
# 19697         90.3  73.7   55.5  58.7  55.1  64.5   753.7          NaN
# 19698        102.7  82.8   71.2  65.2  69.9  68.3   856.1          NaN
# 19701        101.3  78.8   66.5  58.4  56.0  61.4   787.5          NaN
# 19706         90.3  73.0   69.8  78.9  84.6  96.7  1012.1          NaN
# 19781         85.9  76.4   59.0  53.8  51.5  58.5   711.6          NaN
#
# [5709 rows x 16 columns]

# %% [markdown]
# ### Step4: only keep the columns with the monthly means

# %%
#select all row for each month
precip_ref = precip_ref.loc[:,"Jan.":"Dez."]

# %%
precip_ref.loc[399].plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# ---

# %%
# cehck precipitation of Alexanderplatz
precip = pandas.read_csv(
"data/produkt_precipitation_399_akt.txt",
delimiter=" *; *",
encoding = "iso-8859-1",
engine="python")

# %%
precip.head()
# Out:
#    STATIONS_ID  MESS_DATUM  QUALITAETS_NIVEAU  STRUKTUR_VERSION  \
# 0          399  2015082001                  3                 0
# 1          399  2015082002                  3                 0
# 2          399  2015082003                  3                 0
# 3          399  2015082004                  3                 0
# 4          399  2015082005                  3                 0
#
#    NIEDERSCHLAGSHOEHE  eor
# 0                 0.0  eor
# 1                 0.0  eor
# 2                 0.0  eor
# 3                 0.0  eor
# 4                 0.0  eor

# %%
precip["date_time"] = pandas.to_datetime(precip.MESS_DATUM, format="%Y%m%d%H") 
#transform mess_datun into clearer form

# %%
precip["date_time"]
# Out:
# 0       2015-08-20 01:00:00
# 1       2015-08-20 02:00:00
# 2       2015-08-20 03:00:00
# 3       2015-08-20 04:00:00
# 4       2015-08-20 05:00:00
#                 ...
# 89757   2026-04-12 20:00:00
# 89758   2026-04-12 21:00:00
# 89759   2026-04-12 22:00:00
# 89760   2026-04-12 23:00:00
# 89761   2026-04-13 00:00:00
# Name: date_time, Length: 89762, dtype: datetime64[us]

# %%
precip.head()
# Out:
#    STATIONS_ID  MESS_DATUM  QUALITAETS_NIVEAU  STRUKTUR_VERSION  \
# 0          399  2015082001                  3                 0
# 1          399  2015082002                  3                 0
# 2          399  2015082003                  3                 0
# 3          399  2015082004                  3                 0
# 4          399  2015082005                  3                 0
#
#    NIEDERSCHLAGSHOEHE  eor           date_time
# 0                 0.0  eor 2015-08-20 01:00:00
# 1                 0.0  eor 2015-08-20 02:00:00
# 2                 0.0  eor 2015-08-20 03:00:00
# 3                 0.0  eor 2015-08-20 04:00:00
# 4                 0.0  eor 2015-08-20 05:00:00

# %%
precip_alx = precip[["date_time", "NIEDERSCHLAGSHOEHE"]]

# %%
precip_alx.describe()
# Out:
#                         date_time  NIEDERSCHLAGSHOEHE
# count                       89762        89762.000000
# mean   2020-12-22 15:15:47.866580            0.056808
# min           2015-08-20 01:00:00            0.000000
# 25%           2018-04-18 22:15:00            0.000000
# 50%           2020-12-20 16:30:00            0.000000
# 75%           2023-09-10 23:45:00            0.000000
# max           2026-04-13 00:00:00           29.830000
# std                           NaN            0.436938

# %%
precip_alx.NIEDERSCHLAGSHOEHE.plot()
# Out:
# <Axes: >

# %%
precip_alx = precip_alx.rename(columns = {"date_time": "date", "NIEDERSCHLAGSHOEHE": "precipitation"})

# %%
precip_alx.head(20)
# Out:
#                      precipitation
# date
# 2015-08-20 01:00:00            0.0
# 2015-08-20 02:00:00            0.0
# 2015-08-20 03:00:00            0.0
# 2015-08-20 04:00:00            0.0
# 2015-08-20 05:00:00            0.0
# 2015-08-20 06:00:00            0.0
# 2015-08-20 07:00:00            0.0
# 2015-08-20 08:00:00            0.0
# 2015-08-20 09:00:00            0.0
# 2015-08-20 10:00:00            0.0
# 2015-08-20 11:00:00            0.0
# 2015-08-20 12:00:00            0.0
# 2015-08-20 13:00:00            0.0
# 2015-08-20 14:00:00            0.0
# 2015-08-20 15:00:00            0.0
# 2015-08-20 16:00:00            0.0
# 2015-08-20 17:00:00            0.0
# 2015-08-20 18:00:00            0.0
# 2015-08-20 19:00:00            0.0
# 2015-08-20 20:00:00            0.0

# %%
precip_alx = precip_alx.set_index("date")

# %%
precip_alx.plot()
# Out:
# <Axes: xlabel='date'>

# %%
#go from hourly data to monthly data
monthly = precip_alx.resample("ME").sum() 
# resample(): change the frequency in time series data
# "ME" = Month End

# %%
monthly # this is the recent precipitation
# Out:
#             precipitation
# date
# 2015-08-31          18.90
# 2015-09-30          29.19
# 2015-10-31          60.91
# 2015-11-30          58.59
# 2015-12-31          27.34
# ...                   ...
# 2025-12-31          18.73
# 2026-01-31          19.80
# 2026-02-28          48.08
# 2026-03-31          12.36
# 2026-04-30           4.00
#
# [129 rows x 1 columns]

# %%
monthly.describe()
# Out:
#        precipitation
# count     129.000000
# mean       39.528372
# std        28.812164
# min         0.000000
# 25%        22.910000
# 50%        33.640000
# 75%        48.600000
# max       166.300000

# %%
precip_ref #this is the 30 years mean precipitation
# Out:
#              Jan.  Feb.  März  Apr.    Mai  Jun.   Jul.  Aug.  Sept.  Okt.  \
# Stations_id
# 1            48.4  45.6  49.7  51.5   88.7  93.0   95.7  85.1   62.5  61.3
# 2            74.3  66.0  64.4  58.2   70.9  79.8   71.4  69.5   69.7  68.4
# 3            68.1  63.6  67.0  55.7   72.0  80.3   75.2  74.8   69.2  70.0
# 4            68.9  66.1  67.4  55.9   71.5  81.2   75.2  73.2   68.8  69.3
# 6            66.2  65.3  75.2  55.8   93.0  83.0   95.8  79.2   69.8  67.3
# ...           ...   ...   ...   ...    ...   ...    ...   ...    ...   ...
# 19697        54.4  48.5  56.9  42.7   73.6  76.4   90.3  73.7   55.5  58.7
# 19698        59.0  54.4  63.9  57.0   75.8  86.0  102.7  82.8   71.2  65.2
# 19701        46.1  39.8  54.0  52.0   84.1  85.8  101.3  78.8   66.5  58.4
# 19706        89.0  82.0  82.3  69.9  102.4  84.0   90.3  73.0   69.8  78.9
# 19781        47.6  40.1  47.6  42.0   75.1  77.9   85.9  76.4   59.0  53.8
#
#              Nov.  Dez.
# Stations_id
# 1            55.5  60.1
# 2            64.6  78.4
# 3            66.1  75.5
# 4            65.2  76.5
# 6            67.7  80.2
# ...           ...   ...
# 19697        55.1  64.5
# 19698        69.9  68.3
# 19701        56.0  61.4
# 19706        84.6  96.7
# 19781        51.5  58.5
#
# [5709 rows x 12 columns]

# %%
precip_ref.loc[399] #select data only from Alexanderplatz using ID
# Out:
# Jan.     49.0
# Feb.     40.0
# März     45.0
# Apr.     34.0
# Mai      56.0
# Jun.     60.0
# Jul.     64.0
# Aug.     58.0
# Sept.    46.0
# Okt.     39.0
# Nov.     47.0
# Dez.     53.0
# Name: 399, dtype: float64

# %%
monthly.groupby(monthly.index.month).describe()
# Out:
#      precipitation                                                          \
#              count       mean        std    min      25%     50%       75%
# date
# 1             11.0  43.080909  14.963813  19.80  33.0000  45.530   51.7750
# 2             11.0  38.052727  19.801915   3.24  24.7600  39.990   48.1950
# 3             11.0  26.577273  16.599816   1.02  14.3900  27.990   39.2900
# 4             11.0  26.310909  15.251537   1.41  17.0500  29.420   35.6550
# 5             10.0  30.115000  17.810316  10.03  25.2225  27.720   33.1750
# 6             10.0  62.480000  46.832982  22.91  34.4625  42.310   74.5300
# 7             10.0  71.625000  43.327513  27.16  35.3325  55.925  106.2875
# 8             11.0  30.906364  21.515000   4.12  20.4300  27.030   35.8800
# 9             11.0  27.925455  15.035998   1.70  20.0650  29.190   36.3100
# 10            11.0  40.480909  32.242088   0.00  19.8100  32.090   58.9950
# 11            11.0  39.063636  25.046306   0.00  17.9900  38.760   58.7200
# 12            11.0  41.870909  30.349011   0.00  24.3400  39.200   50.5300
#
#
#          max
# date
# 1      69.42
# 2      75.33
# 3      51.87
# 4      47.56
# 5      74.44
# 6     166.30
# 7     136.10
# 8      74.27
# 9      53.48
# 10     95.41
# 11     70.93
# 12    119.06

# %%
monthly.plot()
# Out:
# <Axes: xlabel='date'>

# %%
refs = pandas.DataFrame(
{"precipitation":
precip_ref.loc[399].to_list()*11}, # creat a reference for 11 years by repeat the data 11 times
index = pandas.date_range(
"2015-01-01", "2025-12-31", freq="ME"))

# %%
monthly["climate"] = refs

# %%
monthly.plot()
# Out:
# <Axes: xlabel='date'>

# %%
monthly["anomaly"] = monthly.precipitation - monthly.climate

# %%
monthly.anomaly.plot()
# Out:
# <Axes: xlabel='date'>

# %%
# the example from slides
import numpy
from matplotlib import pyplot
fig, axs = pyplot.subplots(1, figsize=(10,8))
monthly[["climate", "precipitation"]].plot(ax=axs)
axs.set_title("precipitation Berlin, Alexanderplatz")
# Out:
# Text(0.5, 1.0, 'precipitation Berlin, Alexanderplatz')
